# %%
import pandas as pd

# %%
df = pd.read_csv('../Datasets/petrochemical_operations.csv')
df.head(20)
# Out:
#            Timestamp                Unit_Name         Catalyst_Type  \
# 0   01-01-2020 00:00  Methanol_Complex_03          Iron_Standard_V5
# 1   01-01-2020 04:00        Ethylene_Plant_01     Cobalt_Premium_Z2
# 2   01/01/2020 08:00      Methanol_Complex_03     Cobalt_Premium_Z2
# 3   01-01-2020 12:00      Methanol_Complex_03      Platinum_Base_X1
# 4   01-01-2020 16:00        Ethylene_Plant_01     Cobalt_Premium_Z2
# 5   01-01-2020 20:00        Ethylene_Plant_01     Cobalt_Premium_Z2
# 6   02-01-2020 00:00      Methanol_Complex_03  Iron_Standard_V5
# 7   02-01-2020 04:00          Ammonia_Unit_02     Cobalt_PREMIUM_Z2
# 8   02-01-2020 08:00      Methanol_Complex_03      Iron_Standard_V5
# 9   02-01-2020 12:00      Methanol_Complex_03     Cobalt_Premium_Z2
# 10  02-01-2020 16:00      Methanol_Complex_03     Cobalt_Premium_Z2
# 11  02-01-2020 20:00      Methanol_Complex_03     Cobalt_Premium_Z2
# 12  03-01-2020 00:00        Ethylene_Plant_01      Platinum_Base_X1
# ...

# %%
df.shape          # (rows, columns) - dimensions
df.columns        # sirf column names ki list
df.info()         # data types + non-null counts sab columns ka (missing values dhundhne ke liye best)
df.describe()     # numeric columns ka statistical summary (mean, min, max, etc.)
df.isnull().sum() # har column mein kitne missing/null values hain
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10002 entries, 0 to 10001
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Timestamp              10002 non-null  str
#  1   Unit_Name              10002 non-null  str
#  2   Catalyst_Type          10002 non-null  str
#  3   Catalyst_Age_Days      9998 non-null   float64
#  4   Sensor_Health_Index    10002 non-null  float64
#  5   Vibration_Level_mm_s   10002 non-null  float64
#  6   Valve_Opening_Percent  10002 non-null  float64
#  7   Feedstock_Flow_m3h     10002 non-null  float64
#  8   Reactor_Temp_C         10001 non-null  str
#  9   Reactor_Pressure_Bar   9999 non-null   float64
#  10  Electricity_MWh        10002 non-null  float64
#  11  Natural_Gas_m3h        10002 non-null  float64
#  12  Steam_Tons_h           10002 non-null  float64
#  13  Ambient_Temp_C         10002 non-null  float64
# ...
